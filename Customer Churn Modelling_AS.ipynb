# %% [markdown]
# Importing libraries for Data Wrangling and visualisation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %% [markdown]
# READ THE DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# DATA HAS NO NULL VALES. IT HAS 9 COLUMNS WITH INTEGER VALUES, 3 ARE OBJECTS AND 2 COLUMNS WITH FLOAT VALUES

# %% [markdown]
# 1. A. BOXPLOTS

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.boxplot(y='CreditScore',x = 'Exited', hue = 'Exited',data = df)


plt.subplot(1,3,2)
sns.boxplot(y='Age',x = 'Exited', hue = 'Exited',data = df)


plt.subplot(1,3,3)
sns.boxplot(y='Tenure',x = 'Exited', hue = 'Exited',data = df)


plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.boxplot(y='Balance',x = 'Exited', hue = 'Exited',data = df)


plt.subplot(1,3,2)
sns.boxplot(y='NumOfProducts',x = 'Exited', hue = 'Exited',data = df)


plt.subplot(1,3,3)
sns.boxplot(y='EstimatedSalary',x = 'Exited', hue = 'Exited',data = df)

# %% [markdown]
# HERE WE OBSERVE THAT THERE IS NOT MUCH DIFFERENCE IN CREDITSCORE OF RETAINED AND CHURNED CUSTOMER. THERE IS SOME OUTLIERS IN THE CREDIT SCORE OF EXITED CUSTOMERS
#
# YOUNGER PEOPLE ARE LESS LIKELY TO CHURN OUT THEN THE OLDER AGED PEOPLE. ALTHOUGH THERE IS SOME OUTLIERS IN BOTH
#
# CUSTOMERS ASSOCIATED FOR A MUCH LONGER OR SHORTER PERIOD ARE LIKELY TO CHURN OUT, WHEREAS CUSTOMERS ASSOCIATED FOR A MID-AVERAGE PERIOD ARE RETAINED
#
# CUSTOMERS WITH NO TO AVERAGE BALANCE IS RETAINED WHEREAS CHURNED OUT CUSTOMERS HAD SIGNIFICANT BALANCE
#
# NUMBER OF PRODUCTS DOES NOT HAVE MUCH IMPACT ON CHURNING OF CUSTOMERS
#
# SALARY ALSO SEEMS TO HAVE NO IMPACT ON THE CHURNING OF CUSTOMERS

# %% [markdown]
# 1. B. HISTOGRAM

# %%
plt.hist(df['Exited'], bins=2)
# Out:
# (array([7963., 2037.]), array([0. , 0.5, 1. ]), <a list of 2 Patch objects>)

# %%
sns.countplot(df['Exited'],label="Count")
plt.show()

# %% [markdown]
# IN THE ABOVE PLOT WE COULD OBSERVE THAT ONLY ONE-FIFTH OF THE CUSTOMERS HAVE CHURNED OUT

# %% [markdown]
# 1. C. DISTRIBUTION PLOT

# %%
sns.distplot(df['Exited'],bins=2)

# %% [markdown]
# NOT MUCH CAN BE INFERRED FROM THIS PLOT

# %% [markdown]
# 1. D. AGGREGATION OF ALL COLUMNS

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# HERE WE CAN SEE THE COLUMN WISE AGGREGATION. THE BALANCE AND ESTIMATED SALARY COLUMN HAS HIGH STANDARD DEVIATION

# %% [markdown]
# 1. E. UNIQUE VALUES ACROSS ALL COLUMNS

# %%
df.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %% [markdown]
# HERE WE SEE EXCEPT FOR THE COLUMNS WITH CATEGORICAL DATA OTHERS HAVE QUITE LARGE NUMBER OF UNIQUE VALUES

# %% [markdown]
# 1. F. DUPLICATE VALUES ACROSS ALL COLUMNS

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %% [markdown]
# THERE ARE NO DUPLICATE ROWS

# %% [markdown]
# 1. G. CORRELATION HEATMAP

# %%
plt.figure(figsize = (20,20))

sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# HERE WE OBSERVE THAT TENURE,NUMBER OF PRODUCTS,HAS CREDIT CARD AND ESTIMATED SALARY DO NOT HAVE MUCH CORRELATION WITH CHURNING

# %% [markdown]
# 1. H. REGRESSION PLOT

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.regplot(x="CreditScore", y="Exited", data=df);

plt.subplot(1,3,2)
sns.regplot(x="Age", y="Exited", data=df);

plt.subplot(1,3,3)
sns.regplot(x="Tenure", y="Exited", data=df);

plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.regplot(x="Balance", y="Exited", data=df);

plt.subplot(1,3,2)
sns.regplot(x="NumOfProducts", y="Exited", data=df);

plt.subplot(1,3,3)
sns.regplot(x="EstimatedSalary", y="Exited", data=df);

# %% [markdown]
# HERE WE SEE THAT THE CUSTOMERS WITH HIGHER CREDIT SCORE TEND NOT TO CHURN OUT
#
# AS AGE INCREASES CUSTOMERS TEND TO CHURN OUT
#
# TENURE WITH THE BANK VERY THINLY RELATES TO CHURNING OUT
#
# PEOPLE WITH MORE BALANCE TEND TO CHURN OUT
#
# PEOPLE WITH MORE PRODUCTS TEND TO STAY
#
# ESTIMATED SALARY HAVE NOT MUCH OF AN IMPACT ON CHURNING OR STAYING

# %% [markdown]
# 1. I. BAR PLOT

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.barplot(x="Exited", y="Age", data=df[:])


plt.subplot(1,3,2)
sns.barplot(x="Exited", y="Tenure", data=df[:])


plt.subplot(1,3,3)
sns.barplot(x="Exited", y="Balance", data=df[:])

plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.barplot(x="Exited", y="NumOfProducts", data=df[:])


plt.subplot(1,3,2)
sns.barplot(x="Exited", y="EstimatedSalary", data=df[:])


plt.subplot(1,3,3)
sns.barplot(x="Geography", y="Exited", data=df[:])

plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.barplot(x="Gender", y="Exited", data=df[:])

# %% [markdown]
# HERE WE OBSERVE THAT PEOPLE WITH HIGHER AVERAGE AGE TEND TO CHURN OUT
#
# TENURE DONOT HAVE MUCH IMPACT ON CHURNING
#
# PEOPLE WITH HIGHER AVERAGE BALANCE TEND TO CHURN OUT MORE
#
# NUMBER OF PRODUCTS ALSO DONOT HAVE MUCH IMPACT ON CHURNING
#
# ESTIMATED SALARY ALSO DO NOT HAVE MUCH IMPACT ON CHURNING
#
# PEOPLE FROM GERMANY ARE MORE LIKELY TO CHURN OUT
#
# FEMALES TEND TO CHURN OUT MORE

# %% [markdown]
# 1. J. PAIR PLOT

# %%
sns.pairplot(df,hue='Exited',vars=['CreditScore', 'Age', 'Tenure', 'Balance','NumOfProducts','EstimatedSalary']);

# %% [markdown]
# 2. DROP ALL DUPLICATE ROWS

# %% [markdown]
# There are no duplicate Rows in this data set. So we need not drop anything

# %% [markdown]
# 3. DROP ALL NON ESSENTIAL FEATURES

# %%
df = df.drop(["RowNumber", "CustomerId", "Surname", "Tenure", "NumOfProducts", "HasCrCard", "EstimatedSalary"], axis = 1)

# %% [markdown]
# So dropped the above the features or columns those do not impact the outcome or influence customer to churn

# %%
df.describe()
# Out:
#         CreditScore           Age        Balance  IsActiveMember        Exited
# count  10000.000000  10000.000000   10000.000000    10000.000000  10000.000000
# mean     650.528800     38.921800   76485.889288        0.515100      0.203700
# std       96.653299     10.487806   62397.405202        0.499797      0.402769
# min      350.000000     18.000000       0.000000        0.000000      0.000000
# 25%      584.000000     32.000000       0.000000        0.000000      0.000000
# 50%      652.000000     37.000000   97198.540000        1.000000      0.000000
# 75%      718.000000     44.000000  127644.240000        1.000000      0.000000
# max      850.000000     92.000000  250898.090000        1.000000      1.000000

# %% [markdown]
# 4. Replace outliers with Nulls (if you find it essential) and replace all the nulls with respective approach of central tendencies (Mean/Median/Mode).

# %% [markdown]
# There are Outliers in Age and Credit Score data.

# %%
df.boxplot(column = ['Age'])

# %%
df.boxplot(column = ['CreditScore'])

# %%
median = df.loc[df['CreditScore']>400, 'CreditScore'].median()
df.loc[df.CreditScore < 400, 'CreditScore'] = np.nan
df.fillna(median,inplace=True)

mean = df.loc[df['Age']<62, 'Age'].mean()
df.loc[df.Age >62, 'Age'] = np.nan
df.fillna(mean,inplace=True)

# %% [markdown]
# 5. CALCULATING Z-SCORE TO VALIDATE THAT THERE ARE NO OUTLIERS

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df.CreditScore))
print(np.where(z > 3))
z1 = np.abs(stats.zscore(df.Age))
print(np.where(z1 > 3))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %% [markdown]
# HERE WE SEE THAT THERE ARE NO OUTLIERS IN THE DATA

# %% [markdown]
# 6. CLEAN DATA WITH FORMATTING ISSUES

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label1 = LabelEncoder()
df['Geography'] = label1.fit_transform(df['Geography'])
label2 = LabelEncoder()
df['Gender'] = label2.fit_transform(df['Gender'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
# CreditScore       10000 non-null float64
# Geography         10000 non-null int32
# Gender            10000 non-null int32
# Age               10000 non-null float64
# Balance           10000 non-null float64
# IsActiveMember    10000 non-null int64
# Exited            10000 non-null int64
# dtypes: float64(3), int32(2), int64(2)
# memory usage: 468.9 KB

# %% [markdown]
# HERE WE OBSERVE THAT ALL THE DATA ARE NUMERICAL

# %% [markdown]
# 7. ADD YOUR VIEW OF EDA

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.countplot(x='Geography', hue = 'Exited',data = df);


plt.subplot(1,3,2)
sns.countplot(x='Gender', hue = 'Exited',data = df);


plt.subplot(1,3,3)
sns.countplot(x='IsActiveMember', hue = 'Exited',data = df);

# %% [markdown]
# HERE WE CAN SEE THE COUNTRY-WISE, GENDER-WISE AND MEMBER-WISE CHURNING DATA

# %%
plt.figure(figsize=(10,4))
df.corr()['Exited'].sort_values(ascending = False).plot(kind='bar')

# %% [markdown]
# HERE IN THIS BARPLOT WE CAN SEE THE CORRELATION BETWEEN DIFFERENT COLUMNS

# %% [markdown]
# 8. BUILD A MODEL OF YOUR CHOICE

# %%
X = df.drop('Exited',axis = 1)
Y = df['Exited']

# %% [markdown]
# SEPARATE THE X(INDEPENDENT) AND Y(DEPENDENT) VARIABLES

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 50)

# %% [markdown]
# SPLIT THE DATA INTO TRAINING AND TEST SET. 30% TEST DATA AND 70% TRAIN DATA

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import KFold
kf = KFold(n_splits=5)
kf
from sklearn.model_selection import cross_val_score

# %% [markdown]
# IMPORT THE LIBRARIES FOR BUILDING THE MODEL AND CROSS VALIDATION

# %%
from sklearn.model_selection import RandomizedSearchCV , GridSearchCV
import xgboost

# %% [markdown]
# LIBRARY FOR HYPERPARAMETER BOOSTING

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score

# %% [markdown]
# LIBRARIES FOR PERFORMANCE CALCULATION OF MODELS

# %% [markdown]
# LOGISTIC REGRESSION MODEL

# %%
from sklearn import model_selection
lg = LogisticRegression()
lg = lg.fit(X_train, Y_train)
results = model_selection.cross_val_score(lg, X_train, Y_train)
print(results)
Y_pred = lg.predict(X_test)
# Out:
# [0.80071429 0.80571429 0.78928571 0.80142857 0.79428571]

# %%
params = {'C': [0.1,0.5,1,10,50,100],
          'max_iter': [250],
          'fit_intercept':[True],
          'intercept_scaling':[1],
          'penalty':['l2'], 'tol':[0.00001,0.0001,0.000001]}

# %%
random_search=RandomizedSearchCV(lg,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                 dual=False, fit_intercept=True,
#                                                 intercept_scaling=1,
#                                                 l1_ratio=None, max_iter=100,
#                                                 multi_class='auto', n_jobs=None,
#                                                 penalty='l2', random_state=None,
#                                                 solver='lbfgs', tol=0.0001,
#                                                 verbose=0, warm_start=False),
#                    iid='deprecated', n_iter=5, n_jobs=-1,
#                    param_distributions={'C': [0.1, 0.5, 1, 10, 50, 100],
#                                         'fit_intercept': [True],
#                                         'intercept_scaling': [1],
# ...

# %%
random_search.best_estimator_
# Out:
# LogisticRegression(C=50, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=250,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=1e-05, verbose=0,
#                    warm_start=False)

# %%
classifier=xgboost.XGBClassifier(C=50, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=250,
                   multi_class='auto', n_jobs=None, penalty='l2',
                   random_state=None, solver='lbfgs', tol=1e-05, verbose=0,
                   warm_start=False)

# %%
print(confusion_matrix(Y_test,Y_pred))
print(classification_report(Y_test, Y_pred, digits=3))
print(accuracy_score(Y_test,Y_pred))
print(roc_auc_score(Y_test, Y_pred))
# Out:
# [[2323   78]
#  [ 525   74]]
#               precision    recall  f1-score   support
#
#            0      0.816     0.968     0.885      2401
#            1      0.487     0.124     0.197       599
#
#     accuracy                          0.799      3000
#    macro avg      0.651     0.546     0.541      3000
# weighted avg      0.750     0.799     0.748      3000
#
# 0.799
# 0.545526384040039

# %% [markdown]
# The Accuracy of this model is 79.9%
# The Precision of this model is 48.7%
# The Recall score of this model is 12.4%
# The F1 score of this model is 19.7%
# The AUC score for this model is 54.5%

# %% [markdown]
# RANDOM FOREST

# %%
rf = RandomForestClassifier(n_estimators = 50)
rf = rf.fit(X_train, Y_train)
results = model_selection.cross_val_score(rf, X_train, Y_train)
print(results)
Y_pred1 = rf.predict(X_test)
# Out:
# [0.83285714 0.81857143 0.81071429 0.82785714 0.80428571]

# %%
params = {'max_depth': [3, 5, 6, 7, 8], 
              'max_features': [2,4,6,7,8,9],
              'n_estimators':[50,100],
              'min_samples_split': [3, 5, 6, 7]}

# %%
random_search=RandomizedSearchCV(rf,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
# ...

# %%
random_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features=6,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
classifier=xgboost.XGBClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=5, max_features=6,
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=5,
                       min_weight_fraction_leaf=0.0, n_estimators=100,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)

# %%
print(confusion_matrix(Y_test,Y_pred1))
print(classification_report(Y_test, Y_pred1, digits=3))
print(accuracy_score(Y_test,Y_pred1))
print(roc_auc_score(Y_test, Y_pred1))
# Out:
# [[2204  197]
#  [ 379  220]]
#               precision    recall  f1-score   support
#
#            0      0.853     0.918     0.884      2401
#            1      0.528     0.367     0.433       599
#
#     accuracy                          0.808      3000
#    macro avg      0.690     0.643     0.659      3000
# weighted avg      0.788     0.808     0.794      3000
#
# 0.808
# 0.6426148259037865

# %% [markdown]
# The Accuracy of this model is 80.8%
# The Precision of this model is 52.8%
# The Recall score of this model is 36.7%
# The F1 score of this model is 43.3%
# The AUC score for this model is 64.2%

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
dt = DecisionTreeClassifier()
dt = dt.fit(X_train, Y_train)
results = model_selection.cross_val_score(dt, X_train, Y_train)
print(results)
Y_pred2 = dt.predict(X_test)
# Out:
# [0.74785714 0.76071429 0.75857143 0.76285714 0.75357143]

# %%
params = {'max_depth': [3, 5, 6, 7, 8], 
              'max_features': [2,4,6,7,8,9],
              'min_samples_split': [2,3, 5, 6, 7]}

# %%
random_search=RandomizedSearchCV(dt,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     presort='deprecated',
# ...

# %%
random_search.best_estimator_
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=2, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=7,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
classifier=xgboost.XGBClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
                       max_depth=6, max_features=2, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=7,
                       min_weight_fraction_leaf=0.0, presort='deprecated',
                       random_state=None, splitter='best')

# %%
print(confusion_matrix(Y_test,Y_pred2))
print(classification_report(Y_test, Y_pred2, digits=3))
print(accuracy_score(Y_test,Y_pred2))
print(roc_auc_score(Y_test, Y_pred2))
# Out:
# [[1992  409]
#  [ 348  251]]
#               precision    recall  f1-score   support
#
#            0      0.851     0.830     0.840      2401
#            1      0.380     0.419     0.399       599
#
#     accuracy                          0.748      3000
#    macro avg      0.616     0.624     0.620      3000
# weighted avg      0.757     0.748     0.752      3000
#
# 0.7476666666666667
# 0.6243430151182139

# %% [markdown]
# The Accuracy of this model is 74.8%
# The Percision of this model is 38.0%
# The Recall score of this model is 41.9%
# The F1 score of this model is 39.9%
# The AUC score for this model is 62.4%

# %% [markdown]
# KNN CLASSIFIER

# %%
kn = KNeighborsClassifier()
kn = kn.fit(X_train, Y_train)
results = model_selection.cross_val_score(lg, X_train, Y_train)
print(results)
Y_pred3 = kn.predict(X_test)
# Out:
# [0.80071429 0.80571429 0.78928571 0.80142857 0.79428571]

# %%
params = {'n_neighbors' : [5],
        'leaf_size' : [5,8,10,18,25],
         'n_jobs' : [-1,1]}

# %%
random_search=RandomizedSearchCV(kn,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=KNeighborsClassifier(algorithm='auto',
#                                                   leaf_size=30,
#                                                   metric='minkowski',
#                                                   metric_params=None,
#                                                   n_jobs=None, n_neighbors=5,
#                                                   p=2, weights='uniform'),
#                    iid='deprecated', n_iter=5, n_jobs=-1,
#                    param_distributions={'leaf_size': [5, 8, 10, 18, 25],
#                                         'n_jobs': [-1, 1], 'n_neighbors': [5]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='roc_auc', verbose=0)

# %%
random_search.best_estimator_
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=8, metric='minkowski',
#                      metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
classifier=xgboost.XGBClassifier(algorithm='auto', leaf_size=8, metric='minkowski',
                     metric_params=None, n_jobs=1, n_neighbors=5, p=2,
                     weights='uniform')

# %%
print(confusion_matrix(Y_test,Y_pred3))
print(classification_report(Y_test, Y_pred3, digits=3))
print(accuracy_score(Y_test,Y_pred3))
print(roc_auc_score(Y_test, Y_pred3))
# Out:
# [[2211  190]
#  [ 532   67]]
#               precision    recall  f1-score   support
#
#            0      0.806     0.921     0.860      2401
#            1      0.261     0.112     0.157       599
#
#     accuracy                          0.759      3000
#    macro avg      0.533     0.516     0.508      3000
# weighted avg      0.697     0.759     0.719      3000
#
# 0.7593333333333333
# 0.5163596970933786

# %% [markdown]
# The Accuracy of this model is 75.9%
# The Precision of this model is 26.1%
# The Recall score of this model is 11.2%
# The F1 score of this model is 15.7%
# The AUC score for this model is 51.6%

# %% [markdown]
# GAUSSIAN NB

# %%
nb = GaussianNB()
nb = nb.fit(X_train, Y_train)
results = model_selection.cross_val_score(lg, X_train, Y_train)
print(results)
Y_pred4 = nb.predict(X_test)
# Out:
# [0.80071429 0.80571429 0.78928571 0.80142857 0.79428571]

# %%
param_grid = {}

# %%
random_search=GridSearchCV(nb,param_grid,scoring='roc_auc',n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=GaussianNB(priors=None, var_smoothing=1e-09),
#              iid='deprecated', n_jobs=-1, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='roc_auc', verbose=0)

# %%
random_search.best_estimator_
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
classifier=xgboost.XGBClassifier(priors=None, var_smoothing=1e-09)

# %%
print(confusion_matrix(Y_test,Y_pred4))
print(classification_report(Y_test, Y_pred4, digits=3))
print(accuracy_score(Y_test,Y_pred4))
print(roc_auc_score(Y_test, Y_pred4))
# Out:
# [[2252  149]
#  [ 445  154]]
#               precision    recall  f1-score   support
#
#            0      0.835     0.938     0.883      2401
#            1      0.508     0.257     0.341       599
#
#     accuracy                          0.802      3000
#    macro avg      0.672     0.598     0.612      3000
# weighted avg      0.770     0.802     0.775      3000
#
# 0.802
# 0.5975188412730088

# %% [markdown]
# The Accuracy of this model is 80.2%
# The Precision of this model is 50.8%
# The Recall score of this model is 25.7%
# The F1 score of this model is 34.1%
# The AUC score for this model is 59.8%

# %% [markdown]
# 10. ERRORS

# %%
from sklearn import metrics

# %%
mae_lg = round(metrics.mean_absolute_error(Y_test, Y_pred), 4) 
mse_lg = round(metrics.mean_squared_error(Y_test, Y_pred), 4)

# %%
mae_rf = round(metrics.mean_absolute_error(Y_test, Y_pred1), 4) 
mse_rf = round(metrics.mean_squared_error(Y_test, Y_pred1), 4)

# %%
mae_dt = round(metrics.mean_absolute_error(Y_test, Y_pred2), 4) 
mse_dt = round(metrics.mean_squared_error(Y_test, Y_pred2), 4)

# %%
mae_kn = round(metrics.mean_absolute_error(Y_test, Y_pred3), 4) 
mse_kn = round(metrics.mean_squared_error(Y_test, Y_pred3), 4)

# %%
mae_nb = round(metrics.mean_absolute_error(Y_test, Y_pred4), 4) 
mse_nb = round(metrics.mean_squared_error(Y_test, Y_pred4), 4)

# %%
compare_models = pd.DataFrame( 
    {  'Model' : ['LogReg','RanFor','DTree','KNN', 'NB' ],
        'MAE'  : [mae_lg, mae_rf, mae_dt, mae_kn, mae_nb], 
        'MSE'  : [mse_lg, mse_rf, mse_dt, mse_kn, mse_nb] 
    }) 
  
print(compare_models)
# Out:
#     Model     MAE     MSE
# 0  LogReg  0.2010  0.2010
# 1  RanFor  0.1920  0.1920
# 2   DTree  0.2523  0.2523
# 3     KNN  0.2407  0.2407
# 4      NB  0.1980  0.1980

# %% [markdown]
# FROM THE ABOVE SCORES AND ALSO BY COMPARING THE ERRORS WE CAN CONCLUDE THAT THE RANDOM FOREST MODEL IS THE IDEAL ONE FOR THIS DATA SET. ALTHOUGH THE GAUSSIAN NB MODEL HAS ALSO PERFORMED AT PAR WITH THE RANDOM FOREST MODEL

# %% [markdown]
# 13. PREDICTING THE TARGET VARIABLE

# %%
DataFrame = pd.DataFrame({'Actual' : Y_test,'Predicted':Y_pred1})
DataFrame
# Out:
#       Actual  Predicted
# 9102       0          0
# 7868       0          0
# 4176       0          0
# 4161       0          0
# 8770       0          0
# ...      ...        ...
# 6138       1          0
# 6174       0          0
# 3289       0          0
# 5039       0          0
# 3111       0          1
#
# [3000 rows x 2 columns]
